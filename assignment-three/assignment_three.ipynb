# %% [markdown]
# ## Timothy Miller
# ## GTECH 73100, Dr. Sun

# %% [markdown]
# # Assignment Three
# Adjustments to assignment two

# %% [markdown]
# ## Modifications
# I considered several changes to the previous implementation. First, I examined the list and dictionary construction functions to determine whether any of them would be easy to read and more concise as comprehensions. I decided that only `get_county_totals` would be improved with a list comprehension. Next, I considered whether any of the dictionary constructions in task three would benefit from consolidation into a single constructor. For example, the first and third parts both require counting the total counties in each state. However, I decided that keeping them as separate functions made them easier to understand and maintain- this is worth a little bit of duplication. I also considered reusuing mock data between several tests. However, I once again decided that keeping these tests independent of each other was worth a bit of code duplication.
#
# Finally, I reexamined the use of the built-in sort function when sorting the rankings. The rankings list will only ever have one element out of position. I wanted to check whether this knowledge could lead to a more performant custom sorting algorithm that takes advantage of this structure. I created a 'simple bubble' function to sort the rankings. I then compared its performance to the builtin sort. It's worse. But, now I know.
#
# I only included the portions of code with meaningful changes, to help make them easier to read. Ultimately, these changes where limited to a few parts of Task two. Additionally, there are comments noting the modifications.

# %% [markdown]
# ### Import modules

# %%
import json
import io
import time

# %% [markdown]
# ### Read in a data file of all counties in the US.

# %%
# Data Source https://eric.clst.org/assets/wiki/uploads/Stuff/gz_2010_us_050_00_5m.json
# address utf-8 error https://stackoverflow.com/questions/30996289/utf8-codec-cant-decode-byte-0xf3
# Use "with ... as ..." to better handle exceptions
with io.open('data/gz_2010_us_050_00_5m.json', encoding='latin-1') as f:
  data = json.load(f)

features = data['features']

# %% [markdown]
# ### Task 2
#
# Derive the numbers of counties that use these three names, respectively. For each of them, list their county name and state code.

# %%
def get_county_states(features):
  """Format the counties to easily list their states

  Arguments:
  features list[dict] -- county data

  Returns:
  dict[str, list[str]] -- County name as the key and the list of state codes as the value
  """
  county_states = dict()
  for feature in features:
    properties = feature['properties']
    county_name = properties['NAME']
    state_code = properties['STATE']
    county_states.setdefault(county_name, []).append(state_code)

  return county_states


def test_get_county_states():
  mock_features = [{
    'type': 'Feature',
    "properties": {
      'GEO_ID': '0500000US01087',
      'STATE': '01',
      'COUNTY': '087',
      'NAME': 'Macon',
      'LSAD': 'County',
      'CENSUSAREA': 608.885
    },
    "geometry": None,
  }, {
    'type': 'Feature',
    "properties": {
      'GEO_ID': '0500000US02275',
      'STATE': '02',
      'COUNTY': '275',
      'NAME': 'Wrangell',
      'LSAD': 'Cty&Bor',
      'CENSUSAREA': 2541.483
    },
    "geometry": None,
  }, {
    'type': 'Feature',
      'properties': {
      'GEO_ID': '0500000US02270',
      'STATE': '02',
      'COUNTY': '270',
      'NAME': 'Wade Hampton',
      'LSAD': 'CA',
      'CENSUSAREA': 17081.433
    },
    "geometry": None,
  }, {
    'type': 'Feature',
      'properties': {
      'GEO_ID': '',
      'STATE': '03',
      'COUNTY': '',
      'NAME': 'Wade Hampton',
      'LSAD': '',
      'CENSUSAREA': 0
    },
    "geometry": None,
  }]

  expected = {
    "Macon": ["01"],
    "Wrangell": ["02"],
    "Wade Hampton": ["02", "03"]
  }

  obs = get_county_states(mock_features)
  assert(obs == expected)

test_get_county_states()

county_states = get_county_states(features)

def get_county_totals(county_states):
  """Reformat the counties and state list objects into a tuple of counties and their totals

  Arguments:
  county_states dict[str, list[str]] -- County name as the key and the list of state codes as the value

  Returns:
  tuple[str, int] -- The counties and the total number of states that use them.
  """
  # Modified to use list comprehension
  return [(county, len(states)) for county, states in county_states.items()]


def test_get_county_totals():
  mock_county_states = {
    "A": ['0'],
    "B": ['0', '1'],
    "C": ['0', '1', '2']
  }
  expected_count_totals = [('A', 1), ('B', 2), ('C', 3)]
  assert(get_county_totals(mock_county_states) == expected_count_totals)

test_get_county_totals()

# Modification: create simple bubble sort 
def simple_bubble(totals):
  """Sorting based on the assumption that only the first item needs to be 'bubbled up' to its correct space

  Arguments:
  totals list[tuple[str, int]] -- Item Name and total 
  
  Returns:
  None: list is mutated in place 
  """

  target_pos = 0
  compare_pos = 1
  totals_count = len(totals)
  while compare_pos < totals_count and totals[target_pos][1] > totals[compare_pos][1]:
    totals[target_pos], totals[compare_pos] = totals[compare_pos], totals[target_pos]
    target_pos += 1
    compare_pos += 1

def test_simple_bubble():
    mock_totals = [("C", 5), ("B", 0), ("A", 5)]
    expected_totals = [("B", 0), ("C", 5), ("A", 5)]

    # Sort in place
    simple_bubble(mock_totals) 

    assert(mock_totals == expected_totals)

test_simple_bubble() 

# Modification: create function that sorts with a simple bubble sort
def top_k_sort_k_bubble(totals, k):
  """Find the top k values in a tuple of objects and their counts.
  
  Arguments:
  totals tuple[str, int]-- Item Name and total 
  k int -- the number of items to rank

  Returns:
  tuple[str, int] -- Top k items and their counts
  
  Note:
  This function iterates through the list of items, only sorting the list of rankings
  """
  top_k = [(None, 0)]*k
  for total in totals:
    total_val = total[1]
    bottom_k_val = top_k[0][1]
    if total_val > bottom_k_val:
      top_k[0] = total
      simple_bubble(top_k)

  return top_k

def test_top_k_sort_k_simple():
  mock_county_totals = [("A", 0), ("B", 1), ("C", 2), ("D", 3), ("E", 4), ("F", 4)]
  expected_top_k = [("D", 3), ("F", 4), ("E", 4)]

  obs = top_k_sort_k_bubble(mock_county_totals, 3)

  assert(obs == expected_top_k)

test_top_k_sort_k_simple()

def top_k_sort_k(totals, k):
  """Find the top k values in a tuple of objects and their counts.
  
  Arguments:
  totals tuple[str, int]-- Item Name and total 
  k int -- the number of items to rank

  Returns:
  tuple[str, int] -- Top k items and their counts
  
  Note:
  This function iterates through the list of items, only sorting the list of rankings
  """
  top_k = [(None, 0)]*k
  for total in totals:
    total_val = total[1]
    bottom_k_val = top_k[0][1]
    if total_val > bottom_k_val:
      top_k[0] = total
      top_k.sort(key=lambda a: a[1])

  return top_k

def test_top_k_sort_k():
  mock_county_totals = [("A", 0), ("B", 1), ("C", 2), ("D", 3), ("E", 4), ("F", 4)]
  expected_top_k = [("D", 3), ("F", 4), ("E", 4)]
  
  assert(top_k_sort_k(mock_county_totals, 3) == expected_top_k)

test_top_k_sort_k()

county_totals = get_county_totals(county_states)
# Modification: Compare the previous sort of the rankings with the 
# new method that uses a simple bubble
"""
Compare the built-in and simple bumble sort algorithm approaches

Findings: Built in sort is almost always faster
"""
k = 200 
start_time = time.perf_counter()
top_counties = top_k_sort_k(county_totals, k)
stop_time = time.perf_counter()
print(f"top counties built in: {top_counties}")
print(f"top counter built in time: {stop_time - start_time}")

start_time = time.perf_counter()
top_counties_bubble = top_k_sort_k_bubble(county_totals, k)
stop_time = time.perf_counter()
print(f"top counties bubble: {top_counties_bubble}")
print(f"top counter bubble time: {stop_time - start_time}")


"""
Display the top counties and their states
"""
for top_county in top_counties:
  name = top_county[0]
  print(f"{name} county appears in state codes: {county_states[name]}")
# Out:
# top counties built in: [('Vernon', 3), ('Choctaw', 3), ('Ohio', 3), ('Lowndes', 3), ('Murray', 3), ('Cheyenne', 3), ('Hall', 3), ('Buchanan', 3), ('Grayson', 3), ('Gallatin', 3), ('Delta', 3), ('Pawnee', 3), ('Morris', 3), ('Meade', 3), ('Daviess', 3), ('Butte', 3), ('Holmes', 3), ('Seminole', 3), ('Summit', 3), ('Park', 3), ('Baker', 3), ('Sussex', 3), ('Miller', 3), ('Stone', 3), ('Sevier', 3), ('Platte', 3), ('Chippewa', 3), ('Williamson', 3), ('Moore', 3), ('Haskell', 3), ('Fairfield', 3), ('Chester', 3), ('Wyoming', 3), ('Cameron', 3), ('Beaver', 3), ('Stephens', 3), ('McIntosh', 3), ('Potter', 3), ('Buffalo', 3), ('Orleans', 3), ('Oneida', 3), ('Miami', 3), ('Burke', 3), ('Schuyler', 3), ('Christian', 3), ('Lauderdale', 3), ('Rock', 3), ('McPherson', 3), ('Covington', 3), ('Todd', 3), ('St. Louis', 3), ('Pope', 3), ('Osceola', 3), ('Thomas', 3), ('Stevens', 3), ('Osage', 3), ('Edwards', 3), ('Dickinson', 3), ('Comanche', 3), ('Wright', 3), ('Worth', 3), ('Humboldt', 3), ('Claiborne', 3), ('Robertson', 3), ('Nelson', 3), ('McLean', 3), ('Teton', 3), ('Walker', 3), ('Pickens', 3), ('Cedar', 3), ('Noble', 3), ('Stark', 3), ('Coffee', 3), ('Cook', 3), ('Kiowa', 3), ('Cleveland', 3), ('Graham', 3), ('Wood', 4), ('Carbon', 4), ('Fremont', 4), ('Ottawa', 4), ('Russell', 4), ('Camden', 4), ('Middlesex', 4), ('Bedford', 4), ('St. Clair', 4), ('Iron', 4), ('Smith', 4), ('Somerset', 4), ('Wheeler', 4), ('Sherman', 4), ('Lancaster', 4), ('Dawson', 4), ('Blaine', 4), ('Dodge', 4), ('Wilson', 4), ('Linn', 4), ('Grundy', 4), ('Adair', 4), ('Sumter', 4), ('Lamar', 4), ('Van Buren', 4), ('Liberty', 4), ('Phillips', 4), ('Mineral', 4), ('San Juan', 5), ('Dallas', 5), ('Richmond', 5), ('Essex', 5), ('Campbell', 5), ('Houston', 5), ('Henderson', 5), ('Carter', 5), ('Caldwell', 5), ('York', 5), ('Pierce', 5), ('Sheridan', 5), ('Kent', 5), ('Lyon', 5), ('Mitchell', 5), ('Allen', 5), ('Anderson', 5), ('White', 5), ('Clarke', 5), ('Decatur', 5), ('Saline', 5), ('Garfield', 6), ('Floyd', 6), ('Mason', 6), ('Custer', 6), ('Sullivan', 6), ('Livingston', 6), ('Jones', 6), ('
Sherman', 4), ('Lancaster', 4), ('Dawson', 4), ('Blaine', 4), ('Dodge', 4), ('Wilson', 4), ('Linn', 4), ('Grundy', 4), ('Adair', 4), ('Sumter', 4), ('Lamar', 4), ('Van Buren', 4), ('Liberty', 4), ('Phillips', 4), ('Mineral', 4), ('San Juan', 5), ('Dallas', 5), ('Richmond', 5), ('Essex', 5), ('Campbell', 5), ('Houston', 5), ('Henderson', 5), ('Carter', 5), ('Caldwell', 5), ('York', 5), ('Pierce', 5), ('Sheridan', 5), ('Kent', 5), ('Lyon', 5), ('Mitchell', 5), ('Allen', 5), ('Anderson', 5), ('White', 5), ('Clarke', 5), ('Decatur', 5), ('Saline', 5), ('Garfield', 6), ('Floyd', 6), ('Mason', 6), ('Custer', 6), ('Sullivan', 6), ('Livingston', 6), ('Jones', 6), ('DeKalb', 6), ('Newton', 6), ('Martin', 6), ('Delaware', 6), ('Hardin', 6), ('Macon', 6), ('Lafayette', 6), ('Lewis', 7), ('Howard', 7), ('Pulaski', 7), ('Richland', 7), ('Taylor', 7), ('Butler', 8), ('Mercer', 8), ('Harrison', 8), ('Cumberland', 8), ('Webster', 8), ('Cherokee', 8), ('Orange', 8), ('Fulton', 8), ('Boone', 8), ('Jasper', 8), ('Randolph', 8), ('Columbia', 8), ('Knox', 9), ('Brown', 9), ('Shelby', 9), ('Clinton', 9), ('Cass', 9), ('Benton', 9), ('Putnam', 9), ('Perry', 10), ('Hancock', 10), ('Logan', 10), ('Hamilton', 10), ('Henry', 10), ('Pike', 10), ('Crawford', 11), ('Lawrence', 11), ('Fayette', 11), ('Scott', 11), ('Morgan', 11), ('Calhoun', 11), ('Lake', 12), ('Clark', 12), ('Marshall', 12), ('Douglas', 12), ('Polk', 12), ('Lee', 12), ('Johnson', 12), ('Adams', 12), ('Carroll', 13), ('Greene', 14), ('Warren', 14), ('Grant', 15), ('Wayne', 16), ('Monroe', 17), ('Marion', 17), ('Clay', 18), ('Union', 18), ('Montgomery', 18), ('Madison', 20), ('Lincoln', 24), ('Jackson', 24), ('Jefferson', 26), ('Franklin', 26), ('Washington', 31)]
# top counter bubble time: 0.004889680000360386
# Vernon county appears in state codes: ['22', '29', '55']
# Choctaw county appears in state codes: ['01', '28', '40']
# Ohio county appears in state codes: ['21', '18', '54']
# Lowndes county appears in state codes: ['13', '01', '28']
# Murray county appears in state codes: ['27', '13', '40']
# Cheyenne county appears in state codes: ['08', '20', '31']
# Hall county appears in state codes: ['13', '48', '31']
# Buchanan county appears in state codes: ['19', '29', '51']
# Grayson county appears in state codes: ['21', '48', '51']
# Gallatin county appears in state codes: ['21', '17', '30']
# Delta county appears in state codes: ['26', '08', '48']
# Pawnee county appears in state codes: ['20', '40', '31']
# Morris county appears in state codes: ['20', '34', '48']
# Meade county appears in state codes: ['20', '21', '46']
# Daviess county appears in state codes: ['21', '18', '29']
# Butte county appears in state codes: ['06', '16', '46']
# Holmes county appears in state codes: ['12', '28', '39']
# Seminole county appears in state codes: ['12', '13', '40']
# Summit county appears in state codes: ['08', '39', '49']
# Park county appears in state codes: ['08', '30', '56']
# Baker county appears in state codes: ['12', '13', '41']
# Sussex county appears in state codes: ['10', '34', '51']
# Miller county appears in state codes: ['05', '13', '29']
# Stone county appears in state codes: ['05', '29', '28']
# Sevier county appears in state codes: ['05', '47', '49']
# Platte county appears in state codes: ['56', '29', '31']
# Chippewa county appears in state codes: ['55', '26', '27']
# Williamson county appears in state codes: ['48', '17', '47']
# Moore county appears in state codes: ['48', '47', '37']
# Haskell county appears in state codes: ['48', '20', '40']
# Fairfield county appears in state codes: ['45', '09', '39']
# Chester county appears in state codes: ['45', '47', '42']
# Wyoming county appears in state codes: ['42', '36', '54']
# Cameron county appears in state codes: ['42', '22', '48']
# Beaver county appears in state codes: ['42', '40', '49']
# Stephens county appears in state codes: ['40', '48', '13']
# McIntosh county appears in state codes: ['40', '13', '38']
# Potter county appears in state codes: ['46', '42', '48']
# Buffalo county appears in state codes: ['46', '31', '55']
# Orleans county appears in state codes: ['36', '22', '50']
# Oneida county appears in state codes: ['36', '55', '16']
# Miami county appears in state codes: ['39', '20', '18']
# Burke county appears in state codes: ['38', '13', '37']
# Schuyler county appears in state codes: ['29', '17', '36']
# Christian county appears in state codes: ['29', '21', '17']
# Lauderdale county appears in state codes: ['28', '01', '47']
# Rock county appears in state codes: ['31', '27', '55']
# McPherson county appears in state codes: ['31', '20', '46']
# Covington county appears in state codes: ['28', '01', '51']
# Todd county appears in state codes: ['27', '46', '21']
# St. Louis county appears in state codes: ['27', '29', '29']
# Pope county appears in state codes: ['27', '05', '17']
# Osceola county appears in state codes: ['26', '12', '19']
# Thomas county appears in state codes: ['20', '31', '13']
# Stevens county appears in state codes: ['20', '27', '53']
# Osage county appears in state codes: ['20', '29', '40']
# Edwards county appears in state codes: ['20', '17', '48']
# Dickinson county appears in state codes: ['20', '26', '19']
# Comanche county appears in state codes: ['20', '48', '40']
# Wright county appears in state codes: ['19', '29', '27']
# Worth county appears in state codes: ['19', '13', '29']
# Humboldt county appears in state codes: ['19', '06', '32']
# Claiborne county appears in state codes: ['22', '28', '47']
# Robertson county appears in state codes: ['21', '47', '48']
# Nelson county appears in state codes: ['21', '38', '51']
# McLean county appears in state codes: ['21', '17', '38']
# Teton county appears in state codes: ['16', '30', '56']
# Walker county appears in state codes: ['13', '01', '48']
# Pickens county appears in state codes: ['13', '01', '45']
# Cedar county appears in state codes: ['19', '31', '29']
# Noble county appears in state codes: ['18', '40', '39']
# Stark county appears in state codes: ['17', '38', '39']
# Coffee county appears in state codes: ['01', '47', '13']
# Cook county appears in state codes: ['13', '27', '17']
# Kiowa county appears in state codes: ['08', '20', '40']
# Cleveland county appears in state codes: ['05', '40', '37']
# Graham county appears in state codes: ['04', '20', '37']
# Wood county appears in state codes: ['39', '54', '48', '55']
# Carbon county appears in state codes: ['30', '42', '49', '56']
# Fremont county appears in state codes: ['08', '16', '19', '56']
# Ottawa county appears in state codes: ['26', '40', '39', '20']
# Russell county appears in state codes: ['20', '21', '01', '51']
# Camden county appears in state codes: ['13', '37', '34', '29']
# Middlesex county appears in state codes: ['09', '25', '34', '51']
# Bedford county appears in state codes: ['47', '51', '42', '51']
# St. Clair county appears in state codes: ['29', '26', '01', '17']
# Iron county appears in state codes: ['29', '49', '26', '55']
# Smith county appears in state codes: ['28', '20', '47', '48']
# Somerset county appears in state codes: ['34', '23', '42', '24']
# Wheeler county appears in state codes: ['31', '48', '13', '41']
# Sherman county appears in state codes: ['31', '20', '41', '48']
# Lancaster county appears in state codes: ['31', '45', '42', '51']
# Dawson county appears in state codes: ['31', '48', '13', '30']
# Blaine county appears in state codes: ['31', '40', '16', '30']
# Dodge county appears in state codes: ['27', '55', '13', '31']
# Wilson county appears in state codes: ['20', '37', '48', '47']
# Linn county appears in state codes: ['19', '29', '20', '41']
# Grundy county appears in state codes: ['19', '29', '47', '17']
# Adair county appears in state codes: ['19', '21', '29', '40']
# Sumter county appears in state codes: ['01', '13', '12', '45']
# Lamar county appears in state codes: ['01', '13', '28', '48']
# Van Buren county appears in state codes: ['05', '26', '19', '47']
# Liberty county appears in state codes: ['12', '30', '48', '13']
# Phillips county appears in state codes: ['08', '05', '20', '30']
# Mineral county appears in state codes: ['08', '30', '32', '54']
# San Juan county appears in state codes: ['08', '35', '72', '49', '53']
# Dallas county appears in state codes: ['05', '01', '19', '29', '48']
# Richmond county appears in state codes: ['51', '13', '36', '37', '51']
# Essex county appears in state codes: ['50', '25', '36', '34', '51']
# Campbell county appears in state codes: ['56', '21', '47', '46', '51']
# Houston county appears in state codes: ['47', '27', '13', '01', '48']
# Henderson county appears in state codes: ['47', '21', '17', '48', '37']
# Carter county appears in state codes: ['29', '30', '40', '21', '47']
# Caldwell county appears in state codes: ['29', '22', '21', '37', '48']
# York county appears in state codes: ['31', '23', '45', '42', '51']
# Pierce county appears in state codes: ['31', '38', '13', '55', '53']
# Sheridan county appears in state codes: ['30', '38', '20', '31', '56']
# Kent county appears in state codes: ['24', '48', '10', '26', '44']
# Lyon county appears in state codes: ['27', '20', '21', '19', '32']
# Mitchell county appears in state codes: ['19', '48', '13', '37', '20']
# Allen county appears in state codes: ['22', '20', '39', '18', '21']
# Anderson county appears in state codes: ['21', '20', '45', '47', '48']
# White county appears in state codes: ['13', '47', '05', '18', '17']
# Clarke county appears in state codes: ['19', '28', '51', '01', '13']
# Decatur county appears in state codes: ['18', '47', '13', '19', '20']
# Saline county appears in state codes: ['17', '20', '31', '05', '29']
# Garfield county appears in state codes: ['53', '08', '31', '30', '40', '49']
# Floyd county appears in state codes: ['51', '13', '21', '19', '18', '48']
# Mason county appears in state codes: ['53', '26', '21', '17', '48', '54']
# Custer county appears in state codes: ['40', '08', '16', '31', '30', '46']
# Sullivan county appears in state codes: ['29', '42', '18', '47', '36', '33']
# Livingston county appears in state codes: ['26', '21', '22', '17', '36', '29']
# Jones county appears in state codes: ['19', '28', '48', '13', '37', '46']
# DeKalb county appears in state codes: ['17', '29', '13', '01', '18', '47']
# Newton county appears in state codes: ['13', '28', '05', '18', '29', '48']
# Martin county appears in state codes: ['18', '27', '48', '12', '21', '37']
# Delaware county appears in state codes: ['18', '19', '39', '36', '42', '40']
# Hardin county appears in state codes: ['17', '39', '21', '19', '48', '47']
# Macon county appears in state codes: ['01', '17', '13', '47', '29', '37']
# Lafayette county appears in state codes: ['12', '55', '05', '22', '28', '29']
# Lewis county appears in state codes: ['36', '54', '21', '16', '47', '29', '53']
# Howard county appears in state codes: ['24', '31', '48', '05', '19', '18', '29']
# Pulaski county appears in state codes: ['18', '05', '21', '13', '17', '29', '51']
# Richland county appears in state codes: ['17', '55', '22', '30', '38', '45', '39']
# Taylor county appears in state codes: ['12', '48', '21', '13', '19', '54', '55']
# Butler county appears in state codes: ['19', '01', '21', '20', '31', '42', '39', '29']
# Mercer county appears in state codes: ['38', '21', '17', '29', '34', '42', '39', '54']
# Harrison county appears in state codes: ['21', '54', '28', '19', '18', '29', '48', '39']
# Cumberland county appears in state codes: ['17', '23', '51', '21', '47', '37', '34', '42']
# Webster county appears in state codes: ['13', '22', '54', '21', '19', '29', '31', '28']
# Cherokee county appears in state codes: ['19', '13', '01', '20', '45', '37', '40', '48']
# Orange county appears in state codes: ['18', '37', '12', '06', '36', '51', '48', '50']
# Fulton county appears in state codes: ['18', '05', '13', '21', '17', '36', '39', '42']
# Boone county appears in state codes: ['18', '17', '05', '19', '21', '31', '29', '54']
# Jasper county appears in state codes: ['17', '28', '13', '19', '18', '29', '48', '45']
# Randolph county appears in state codes: ['01', '13', '29', '37', '05', '18', '17', '54']
# Columbia county appears in state codes: ['05', '36', '53', '12', '13', '41', '42', '55']
# Knox county appears in state codes: ['29', '21', '23', '17', '18', '47', '31', '39', '48']
# Brown county appears in state codes: ['17', '20', '31', '46', '27', '18', '39', '55', '48']
# Shelby county appears in state codes: ['18', '19', '01', '17', '47', '29', '21', '39', '48']
# Clinton county appears in state codes: ['18', '21', '26', '29', '19', '17', '36', '42', '39']
# Cass county appears in state codes: ['18', '38', '26', '27', '19', '17', '31', '29', '48']
# Benton county appears in state codes: ['18', '27', '29', '47', '05', '19', '28', '41', '53']
# Putnam county appears in state codes: ['12', '17', '18', '39', '36', '13', '47', '29', '54']
# Perry county appears in state codes: ['05', '18', '21', '01', '17', '47', '29', '28', '42', '39']
# Hancock county appears in state codes: ['23', '21', '13', '28', '19', '18', '17', '47', '39', '54']
# Logan county appears in state codes: ['21', '20', '39', '08', '05', '17', '40', '31', '38', '54']
# Hamilton county appears in state codes: ['17', '19', '36', '48', '12', '20', '47', '18', '31', '39']
# Henry county appears in state codes: ['18', '21', '19', '13', '01', '29', '47', '17', '39', '51']
# Pike county appears in state codes: ['05', '21', '39', '18', '13', '01', '17', '29', '28', '42']
# Crawford county appears in state codes: ['19', '26', '39', '05', '13', '18', '17', '20', '29', '42', '55']
# Lawrence county appears in state codes: ['18', '28', '29', '47', '05', '21', '01', '17', '42', '39', '46']
# Fayette county appears in state codes: ['18', '19', '39', '47', '48', '13', '21', '01', '17', '42', '54']
# Scott county appears in state codes: ['17', '28', '51', '05', '18', '20', '21', '27', '19', '47', '29']
# Morgan county appears in state codes: ['01', '08', '21', '13', '17', '18', '47', '29', '39', '54', '49']
# Calhoun county appears in state codes: ['12', '28', '26', '54', '05', '13', '19', '01', '17', '45', '48']
